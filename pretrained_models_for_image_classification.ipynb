# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
from keras.preprocessing import image

# %%
model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
img_path = '/content/cat'
img = image.load_img(img_path, target_size = (224, 224))
x  = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
print("Predicted", decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Predicted [('n02124075', 'Egyptian_cat', np.float32(0.2570579)), ('n02123159', 'tiger_cat', np.float32(0.24932852)), ('n02909870', 'bucket', np.float32(0.079323575))]

# %%
img_path = '/content/dog'
img = image.load_img(img_path, target_size = (224, 224))
x  = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted", decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Predicted [('n02106550', 'Rottweiler', np.float32(0.99908996)), ('n02107908', 'Appenzeller', np.float32(0.0007532006)), ('n02107142', 'Doberman', np.float32(6.944671e-05))]

# %%
img_path = '/content/car.jpg'
img = image.load_img(img_path, target_size = (224, 224))
x  = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted", decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# Predicted [('n03930630', 'pickup', np.float32(0.3123174)), ('n04037443', 'racer', np.float32(0.25802273)), ('n04285008', 'sports_car', np.float32(0.21576706))]

# %%
img_path = '/content/human.jpg'
img = image.load_img(img_path, target_size = (224, 224))
x  = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted", decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# Predicted [('n03724870', 'mask', np.float32(0.5197062)), ('n03000247', 'chain_mail', np.float32(0.186794)), ('n04229816', 'ski_mask', np.float32(0.0330603))]

# %%
img_path = '/content/IMG-20241018-WA0082.jpg'
img = image.load_img(img_path, target_size = (224, 224))
x  = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted", decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# Predicted [('n02837789', 'bikini', np.float32(0.22746478)), ('n04584207', 'wig', np.float32(0.13417915)), ('n04136333', 'sarong', np.float32(0.10258705))]

# %%
img_path = '/content/kwala.jpg'
img = image.load_img(img_path, target_size = (224, 224))
x  = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted", decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# Predicted [('n01882714', 'koala', np.float32(0.99025285)), ('n02132136', 'brown_bear', np.float32(0.0027388353)), ('n02497673', 'Madagascar_cat', np.float32(0.00090892677))]

# %%
img_path = '/content/strawberry.jpg'
img = image.load_img(img_path, target_size = (224, 224))
x  = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted", decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# Predicted [('n07745940', 'strawberry', np.float32(0.99955064)), ('n07753275', 'pineapple', np.float32(0.0003209966)), ('n01514668', 'cock', np.float32(1.7624465e-05))]
